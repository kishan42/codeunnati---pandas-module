# %%
import pandas as pd

import numpy as np

dict = {'First name':[100,90,np.nan,95],'second score':[100,90,80,np.nan],'third score':[np.nan,95,43,56]}

df = pd.DataFrame(dict)

df.isnull()   #find null value
# Out:
#    First name  second score  third score
# 0       False         False         True
# 1       False         False        False
# 2        True         False        False
# 3       False          True        False

# %%
data = pd.read_csv("ds1.csv")

bool_series = pd.isnull(data["Gender"])   #find null values

data[bool_series]
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 1  940761         Ms.     Brenda              S  Robinson    NaN
#
#                       E Mail     Father's Name  Mother's Name  \
# 1  brenda.robinson@gmail.com  Raymond Robinson  Judy Robinson
#
#   Mother's Maiden Name  Salary
# 1                Perry   51063

# %%
bool_series1 = pd.isnull(data['Middle Initial'])

data[bool_series1]
# Out:
# Empty DataFrame
# Columns: [Emp ID, Name Prefix, First Name, Middle Initial, Last Name, Gender, E Mail, Father's Name, Mother's Name, Mother's Maiden Name, Salary]
# Index: []

# %%
data = pd.read_csv("ds1.csv")

bool_series = pd.notnull(data["Gender"])   # find not null values

data[bool_series]
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0   677509        Drs.       Lois              H    Walker      F
# 2   428945         Dr.        Joe              W  Robinson      M
# 3   408351        Drs.      Diane              I     Evans      F
# 4   193819         Mr.   Benjamin              R   Russell      M
# 5   499687         Mr.    Patrick              F    Bailey      M
# ..     ...         ...        ...            ...       ...    ...
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                           E Mail    Father's Name       Mother's Name  \
# 0        lois.walker@hotmail.com    Donald Walker        Helen Walker
# ...

# %%
data = pd.read_csv('employees.csv')

bool_series = pd.isnull(data)

print(bool_series)
data[bool_series]
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0         False   False       False            False   False    False
# 1         False   False       False            False   False    False
# 2         False   False       False            False   False    False
# 3         False   False       False            False   False    False
# 4         False   False       False            False   False    False
# ..          ...     ...         ...              ...     ...      ...
# 995       False    True       False            False   False    False
# 996       False   False       False            False   False    False
# 997       False   False       False            False   False    False
# 998       False   False       False            False   False    False
# 999       False   False       False            False   False    False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# ...

# %%
series1 = pd.isnull(data["Team"])

print(series1)
data[series1]

bool_series2 = pd.isnull(data["First Name"])

print(series2)
data[series2]
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: First Name, Length: 1000, dtype: bool
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 7          NaN  Female  7/20/2015        10:43 AM   45906   11.598
# 23         NaN    Male  6/14/2012         4:19 PM  125792    5.042
# 25         NaN    Male  10/8/2012         1:12 AM   37076   18.576
# 32         NaN    Male  8/21/1998         2:27 PM  122340    6.417
# 39         NaN    Male  1/29/2016         2:33 AM  122173    7.797
# ..         ...     ...        ...             ...     ...      ...
# 902        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# ...

# %%
dict = {'First name':[100,90,np.nan,95],'second score':[100,90,80,np.nan],'third score':[np.nan,95,43,56]}

df = pd.DataFrame(dict)

df.isnull()   #find null value
# Out:
#    First name  second score  third score
# 0       False         False         True
# 1       False         False        False
# 2        True         False        False
# 3       False          True        False

# %%
df.dropna()    # drop null values
# Out:
#    First name  second score  third score
# 1        90.0          90.0         95.0
